# %%
import numpy as np
import pandas as pd

np.random.seed(42)

# 20 Samples, 20 Features
X = pd.DataFrame(
    np.random.randn(20, 20),
    columns=[f"feature_{i}" for i in range(20)]
)

# 2 Klassen für PLS-DA
y = np.array([0]*10 + [1]*10)

X
# Out:
#     feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0    0.496714  -0.138264   0.647689   1.523030  -0.234153  -0.234137
# 1    1.465649  -0.225776   0.067528  -1.424748  -0.544383   0.110923
# 2    0.738467   0.171368  -0.115648  -0.301104  -1.478522  -0.719844
# 3   -0.479174  -0.185659  -1.106335  -1.196207   0.812526   1.356240
# 4   -0.219672   0.357113   1.477894  -0.518270  -0.808494  -0.501757
# 5   -1.415371  -0.420645  -0.342715  -0.802277  -0.161286   0.404051
# 6    0.791032  -0.909387   1.402794  -1.401851   0.586857   2.190456
# 7    0.227460   1.307143  -1.607483   0.184634   0.259883   0.781823
# 8   -0.974682   0.787085   1.158596  -0.820682   0.963376   0.412781
# 9    0.625667  -0.857158  -1.070892   0.482472  -0.223463   0.714000
# 10   0.357787   0.560785   1.083051   1.053802  -1.377669  -0.937825
# 11   2.314659  -1.867265   0.686260  -1.612716  -0.471932   1.088951
# 12  -0.792521  -0.114736   0.504987   0.865755  -1.200296  -0.334501
# ...

# %%
import sys
sys.path.append("/home/tryndaron/software_projekte/python_projectyx/Data_Engineering/Data-Engineering-standard-funkionen")  # z.B. /home/user/datasci_pipeline

# %%
from datasci_automation.preprocessing.PCA import PCAStep
from datasci_automation.preprocessing.standardize import StandardizeStep
from datasci_automation.preprocessing.nan_imputer import NanImputerStep
#from datasci_automation.models.plsda import PLSDAClassifier

# %%
from datasci_automation.reporting.summary import dataframe_summary

summary, pd_summary = dataframe_summary(X)
pd_summary
# Out:
#               dtype missing missing_pct unique      mean       std       min  \
# feature_0   float64       0         0.0     20    0.0224  0.933685 -1.415371
# feature_1   float64       0         0.0     20  0.013961  0.795268 -1.867265
# feature_2   float64       0         0.0     20 -0.046407  1.291508 -3.241267
# feature_3   float64       0         0.0     20  -0.20793  1.059098 -1.612716
# feature_4   float64       0         0.0     20 -0.178202  0.891301 -1.478522
# feature_5   float64       0         0.0     20  0.000783  0.978708 -1.952088
# feature_6   float64       0         0.0     20  0.245175    1.0016 -1.448084
# feature_7   float64       0         0.0     20   0.11333  1.003294 -1.430141
# feature_8   float64       0         0.0     20  0.089968  0.663284 -0.846794
# feature_9   float64       0         0.0     20  -0.04427  1.138424  -1.76304
# feature_10  float64       0         0.0     20 -0.290884  0.787765 -1.918771
# ...

# %%
pipeline = [
    NanImputerStep(),
    StandardizeStep(),
    PCAStep(n_components=5),
    #PLSDAClassifier(n_components=2)
]




pipeline
